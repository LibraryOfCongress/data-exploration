# %%
import requests

def get_image_urls(url, items=[]):
    '''
    Retrieves the image URLs for items that have public URLs available. 
    Skips over items that are for the colletion as a whole or web pages about the collection.
    Handles pagination. 
    '''
    
    
    # @TODO clean out anomalies
    # ex: {
    #  'work': 'http://www.loc.gov/item/48036706/',
    #  'volume': 'https://www.loc.gov/resource/muspre1800.101266/'
    # }
    # Also: 'https://www.loc.gov/resource/rbctos.2017rosen1137/'
    
    # request pages of 100 results at a time
    params = {"fo": "json", "c": 100, "at": "results,pagination"}
    call = requests.get(url, params=params)
    data = call.json()
    results = data['results']
    
#     print(results)
    
    for result in results:
        if "collection" not in result.get("original_format") and "web page" not in result.get("original_format"):
            
            id = result.get("id");
            for segment in result.get("segments") or result.get("resources"):
                
                image_list = segment["url"].split('/')[-2].split('.')
    
                cdn = f"https://cdn.loc.gov/service/rbc/{image_list[0]}/{image_list[1][:4]}/{image_list[1]}/"
                
                item = {"work" : id, "volume" : segment["url"], "cdn" : cdn }
                items.append(item)     
                            

    if data["pagination"]["next"] is not None: # make sure we haven't hit the end of the pages
        next_url = data["pagination"]["next"]
        print("getting next page: {0}".format(next_url))
        get_image_urls(next_url, items)
        
    print(items)
    return items

# %%
# ?sp=2
work_volume_list = get_image_urls("https://www.loc.gov/collections/lessing-j-rosenwald/", items=[])
# Out:
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=2
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=3
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=4
# [{'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v3/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v1/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v1/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v4/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v4/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v2/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v2/'}, {'work': 'http://www.loc.gov/item/65059076/', 'volume': 'https://www.loc.gov/resource/rbctos.2017rosen1137/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbctos/2017/2017rosen1137/'}, {'work': 'http://www.loc.gov/item/46028327/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1431/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1431/'}, {'work': 'http://www.loc.gov/item/66089554/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1432/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1432/'}, {'work': 'http://www.loc.gov/item/65058999/', 'volume': 'https://www.loc.gov/resource/rbc0001.2014rosen1131/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2014/2014rosen1131/'}, {'work': 'http://www.loc.gov/item/49030941/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen1133/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen1133/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967a/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967a/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967b/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967b/'}, {'work': 'http://www.loc.gov/item/48037381/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen0881/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen0881/'}, {'work': 'http://www.loc.gov/item/48033299/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1284/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1284/'}, {'work': 'http://www.loc.gov/item/48034140/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0193/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0193/'}, {'work': 'http://www.loc.gov/item/48034144/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0195/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0195/'}, {'work': 'http://www.loc.gov/item/48034881/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0196/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0196/'}, {'work': 'http://www.loc.gov/item/47043543/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0744/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen
', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2003/2003rosen1094/'}, {'work': 'http://www.loc.gov/item/54001909/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen0923/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen0923/'}, {'work': 'http://www.loc.gov/item/65059067/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen1299/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen1299/'}, {'work': 'http://www.loc.gov/item/48042317/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0097/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/ ...

# %%
len(work_volume_list)
# Out:
# 357

# %%
work_volume_list[:5]
# Out:
# [{'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v3/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v1/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v4/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v2/'},
#  {'work': 'http://www.loc.gov/item/65059076/',
#   'volume': 'https://www.loc.gov/resource/rbctos.2017rosen1137/'}]

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
import os
from requests.exceptions import HTTPError

# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0001v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0002v.jpg

def get_image_files(image_urls_list, dir_name):
    '''
    Takes as input a list of URLs for loc.gov item pages and 
    a path to a directory in which to save image files, e.g. "data". 
    '''    
    for count, url in enumerate(image_urls_list):
                
        if count % 100 == 0:
            print("at item {0}".format(count))
        
        # for each volume, initialize first image
        i = 1
        
        # function checks if image exists
        def url_validator(url):
            try:
                r = requests.get(url)
                r.raise_for_status()
                
            except HTTPError:
                
                return "404"
        
        # assume each volume has at least one image, "0001"
        is_valid_url = "200"
            
        while (is_valid_url != "404"):
                         
            try:
                # create a string in format "0001", ..."0254"
                image = str(i).zfill(4)

                # http://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0254v.jpg
                full_url = f"{url['cdn']}{image}v.jpg"

                # do some ugly stuff to generate an image name for download
                string_array = full_url.split("/")
                
                image_name = "-".join(string_array[5:])

                filename = os.path.join(dir_name, image_name)       

                # @TODO refactor to use image_response to check url validity
                image_response = requests.get(full_url, stream=True)
                
                print(image_response)

                with open(filename, 'wb') as fd:
                    for chunk in image_response.iter_content(chunk_size=100000):
                        fd.write(chunk)
                
                # increment image number
                i += 1
                
                # don't repeat yourself!
                image = str(i).zfill(4)

                full_url = f"{url['cdn']}{image}v.jpg"
                
                # check if the new image url is valid
                is_valid_url = url_validator(full_url)

            except ConnectionError as e:
                print(e)

# %%
get_image_files(work_volume_list, "images")
# Out:
# at item 0
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# <Response [404]>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-8f17ec3ebc0e> in <module>
# ----> 1 get_image_files(work_volume_list, "images")
#
# <ipython-input-159-c772c849d056> in get_image_files(image_urls_list, dir_name)
#      47                 filename = os.path.join(dir_name, image_name)
#      48
# ---> 49                 image_response = requests.get(full_url, stream=True)
#      50
#      51                 print(image_response)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
! ls -la images
# Out:
# total 28
# drwxr-xr-x 2 jarednielsen jarednielsen 20480 Sep  8 14:58 .
# drwxr-xr-x 9 jarednielsen jarednielsen  4096 Sep  8 15:04 ..
# -rw-r--r-- 1 jarednielsen jarednielsen   324 Sep  8 14:59 0001v.jpg

# %% [markdown]
# ### Connecting the image file to the metadata
# The filename the code creates is the item's identifier, so you reconstruct a URL for the item's metadata. For example, to examine at the metadata for the first item in the list, 2007685715.jpg, you can add ``https://www.loc.gov/item/`` before the identifier.
#
# ``https://www.loc.gov/item/2007685715``
#
# You can also request the metadata in JSON format by adding ``?fo=json&at=item`` at the end.

# %%
r = requests.get("https://www.loc.gov/item/2007685715/?fo=json")
r_data = r.json()
print(json.dumps(r_data["item"], indent=2))
# Out:
# {
#   "format": [
#     {
#       "photo, print, drawing": "https://www.loc.gov/search/?fa=original_format:photo,+print,+drawing&fo=json"
#     }
#   ],
#   "subject_headings": [
#     "Marquard, Rube (Team member)",
#     "New York Giants",
#     "New York",
#     "National League",
#     "pitcher"
#   ],
#   "id": "2007685715",
#   "medium": [
#     "1 print : relief with halftone, color."
#   ],
#   "marc": "//www.loc.gov/pictures/item/2007685715/marc/",
#   "other_formats": [
#     {
#       "link": "https://lccn.loc.gov/2007685715/marcxml",
#       "label": "MARCXML Record"
#     },
#     {
#       "link": "https://lccn.loc.gov/2007685715/mods",
#       "label": "MODS Record"
#     },
#     {
#       "link": "https://lccn.loc.gov/2007685715/dc",
#       "label": "Dublin Core Record"
#     }
#   ],
#   "sort_date": "1912",
#   "summary": "",
#   "rights": [
#     "<p>The Library of Congress does not&nbsp;own rights to material  in its collections. Therefore, it does not license or charge permission fees  for use of such material and cannot grant or deny permission to publish or  otherwise distribute the material. </p>\n<p>Ultimately, it is the researcher's obligation to assess copyright or other use restrictions and  obtain permission from third parties when necessary before publishing or  otherwise distributing materials found in the Library's collections. </p>\n<p>For information about reproducing,  publishing, and citing material from this collection, as well as access to the  original items, see: <a href=\"//www.loc.gov/rr/print/res/620_base.html\">Baseball Cards from the Benjamin K. Edwards Collection - Rights and Restrictions Information</a> </p>\n \n"
#   ],
#   "description": [
#     "1 print : relief with halftone, color."
#   ],
#   "library_of_congress_control_number": "2007685715",
#   "source_modified": "2007-11-06 15:19:07",
#   "control_number": "",
#   "rights_information": "No known restrictions on publication.",
#   "related_items": [],
#   "dates": [
#     {
#       "1912": "https://www.loc.gov/search/?dates=1912/1912&fo=json"
#     }
#   ],
#   "service_low": "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067f_150px.jpg",
#   "aka": [
#     "http://www.loc.gov/pictures/collection/bbc/item/2007685715/",
#     "http://hdl.loc.gov/loc.pnp/bbc.2067b",
#     "http://www.loc.gov/item/2007685715/",
#     "http://www.loc.gov/pictures/item/2007685715/",
#     "http://hdl.loc.gov/loc.pnp/bbc.2067f",
#     "http://www.loc.gov/resource/bbc.2067f/",
#     "http://www.loc.gov/resource/bbc.2067b/",
#     "http://lccn.loc.gov/2007685715"
#   ],
#   "contributors": [
#     {
#       "honest long cut and miners extra brands": "https://www.loc.gov/search/?fa=contributor:honest+long+cut+and+miners+extra+brands&fo=json"
#     }
#   ],
#   "notes": [
#     "Baseball card title devised by Library staff.",
#     "Issued by: Honest Long Cut and Miners Extra brands.",
#     "Forms part of: Baseball cards from the Benjamin K. Edwards Collection."
#   ],
#   "mime_type": [
#     "image/gif",
#     "image/jpg",
#     "image/tif",
#     "image/jpeg"
#   ],
#   "other_title": [
#     "Card set: Series of Champions (T227)"
#   ],
#   "index": 1,
#   "reproductions": [],
#   "subject": [
#     "marquard, rube (team member)",
#     "new york giants",
#     "new york",
#     "national league",
#     "pitcher",
#     "baseball cards",
#     "relief prints",
#     "color"
#   ],
#   "online_format": [
#     "image"
#   ],
#   "display_offsite": true,
#   "shelf_id": "LOT 13163-32, no. 1 [P&P]",
#   "subjects": [
#     {
#       "baseball cards": "https://www.loc.gov/search/?fa=subject:baseball+cards&fo=json"
#     },
#     {
#       "color": "https://www.loc.gov/search/?fa=subject:color&fo=json"
#     },
#     {
#       "marquard, rube (team member)": "https://www.loc.gov/search/?fa=subject:marquard,+rube+%28team+member%29&fo=json"
#     },
#     {
#       "national league": "https://www.loc.gov/search/?fa=subject:national+league&fo=json"
#     },
#     {
#       "new york": "https://www.loc.gov/search/?fa=subject:new+york&fo=json"
#     },
#     {
#       "new york giants": "https://www.loc.gov/search/?fa=subject:new+york+giants&fo=json"
#     },
#     {
#       "pitcher": "https://www.loc.gov/search/?fa=subject:pitcher&fo=json"
#     },
#     {
#       "relief prints": "https://www.loc.gov/search/?fa=subject:relief+prints&fo=json"
#     }
#   ],
#   "format_headings": [
#     "Baseball cards--1910-1920.",
#     "Relief prints--Color--1910-1920."
#   ],
#   "source_collection": "Baseball cards from the Benjamin K. Edwards Collection",
#   "created_published_date": "1912.",
#   "site": [
#     "pictures",
#     "catalog"
#   ],
#   "language": [
#     {
#       "english": "https://www.loc.gov/search/?fa=language:english&fo=json"
#     }
#   ],
#   "image_url": [
#     "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067f_150px.jpg",
#     "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067f_150px.jpg#h=150&w=103",
#     "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067ft.gif#h=150&w=103",
#     "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067fr.jpg#h=640&w=441",
#     "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067fv.jpg#h=1024&w=705"
#   ],
#   "resource_links": [
#     "//hdl.loc.gov/loc.pnp/bbc.2067f",
#     "//hdl.loc.gov/loc.pnp/bbc.2067b"
#   ],
#   "creator": null,
#   "source_created": "2007-10-19 00:00:00",
#   "part_of_group": null,
#   "original_format": [
#     "photo, print, drawing"
#   ],
#   "other_number": "",
#   "restriction": "Restricted access: Materials in this collection are extremely fragile and cannot be served.",
#   "repository": [
#     "Library of Congress Prints and Photographs Division Washington, D.C. 20540 USA"
#   ],
#   "group": [
#     "bbc",
#     "catalog",
#     "baseball-cards"
#   ],
#   "group_has_items": false,
#   "access_restricted": false,
#   "service_medium": "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067fr.jpg",
#   "contributor_names": [
#     "Honest Long Cut and Miners Extra brands, sponser"
#   ],
#   "medium_brief": "1 print :",
#   "type": [
#     "photo, print, drawing"
#   ],
#   "partof": [
#     {
#       "url": "https://www.loc.gov/search/?fa=partof:baseball+cards,+1887-1914&fo=json",
#       "count": 2085,
#       "title": "baseball cards, 1887-1914"
#     },
#     {
#       "url": "https://www.loc.gov/search/?fa=partof:lot+13163&fo=json",
#       "count": 2085,
#       "title": "lot 13163"
#     },
#     {
#       "url": "https://www.loc.gov/collections/baseball-cards/?fo=json",
#       "count": 2092,
#       "title": "baseball cards"
#     },
#     {
#       "url": "https://www.loc.gov/search/?fa=partof:american+memory&fo=json",
#       "count": 515254,
#       "title": "american memory"
#     },
#     {
#       "url": "https://www.loc.gov/search/?fa=partof:catalog&fo=json",
#       "count": 919048,
#       "title": "catalog"
#     },
#     {
#       "url": "https://www.loc.gov/search/?fa=partof:prints+and+photographs+division&fo=json",
#       "count": 979756,
#       "title": "prints and photographs division"
#     }
#   ],
#   "digitized": true,
#   "modified": "2016-04-20 16:34:00",
#   "call_number": "LOT 13163-32, no. 1 [P&P]",
#   "location": [],
#   "created_published": [
#     "1912."
#   ],
#   "score": 12.015535,
#   "terms": [],
#   "date": "1912.",
#   "extract_urls": [
#     "http://www.loc.gov/pictures/collection/bbc/item/2007685715/#bbc",
#     "http://lccn.loc.gov/2007685715#catalog"
#   ],
#   "_version_": 1534613133176340480,
#   "thumb_gallery": "//cdn.loc.gov/service/pnp/bbc/2000/2060/2067f_150px.jpg",
#   "contents": "",
#   "hassegments": false,
#   "created": "2016-04-20 16:34:00",
#   "digital_id": [
#     "bbc 2067f //hdl.loc.gov/loc.pnp/bbc.2067f",
#     "bbc 2067b //hdl.loc.gov/loc.pnp/bbc.2067b"
#   ],
#   "extract_timestamp": "2016-05-17T21:36:22.123Z",
#   "campaigns": [],
#   "url": "https://www.loc.gov/item/2007685715/",
#   "timestamp": "2016-05-17T21:38:50.561Z",
#   "place": [],
#   "access_advisory": "Restricted access: Materials in this collection are extremely fragile and cannot be served.",
#   "rights_advisory": "No known restrictions on publication.",
#   "link": "//www.loc.gov/pictures/item/2007685715/",
#   "title": "[Richard Marquard, New York Giants, baseball card portrait]",
#   "title_translation": "",
#   "stmt_of_responsibility": "",
#   "reproduction_number": "LC-DIG-bbc-2067f (digital file from original, front)\nLC-DIG-bbc-2067b (digital file from original, back)"
# }
