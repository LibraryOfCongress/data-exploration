# %%
import requests

def get_image_urls(url, items=[]):
    '''
    Retrieves the image URLs for items that have public URLs available. 
    Skips over items that are for the colletion as a whole or web pages about the collection.
    Handles pagination. 
    '''
    
    
    # @TODO clean out anomalies
    # ex: {
    #  'work': 'http://www.loc.gov/item/48036706/',
    #  'volume': 'https://www.loc.gov/resource/muspre1800.101266/'
    # }
    # Also: 'https://www.loc.gov/resource/rbctos.2017rosen1137/'
    
    # request pages of 100 results at a time
    params = {"fo": "json", "c": 100, "at": "results,pagination"}
    call = requests.get(url, params=params)
    data = call.json()
    results = data['results']
    
#     print(results)
    
    for result in results:
        if "collection" not in result.get("original_format") and "web page" not in result.get("original_format"):
            
            id = result.get("id");
            for segment in result.get("segments") or result.get("resources"):
                
                image_list = segment["url"].split('/')[-2].split('.')
    
                cdn = f"https://cdn.loc.gov/service/rbc/{image_list[0]}/{image_list[1][:4]}/{image_list[1]}/"
                
                item = {"work" : id, "volume" : segment["url"], "cdn" : cdn }
                items.append(item)     
                            

    if data["pagination"]["next"] is not None: # make sure we haven't hit the end of the pages
        next_url = data["pagination"]["next"]
        print("getting next page: {0}".format(next_url))
        get_image_urls(next_url, items)
        
    print(items)
    return items

# %%
# ?sp=2
work_volume_list = get_image_urls("https://www.loc.gov/collections/lessing-j-rosenwald/", items=[])
# Out:
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=2
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=3
# getting next page: https://www.loc.gov/collections/lessing-j-rosenwald/?at=results,pagination&c=100&fo=json&sp=4
# [{'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v3/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v1/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v1/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v4/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v4/'}, {'work': 'http://www.loc.gov/item/51006716/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v2/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v2/'}, {'work': 'http://www.loc.gov/item/65059076/', 'volume': 'https://www.loc.gov/resource/rbctos.2017rosen1137/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbctos/2017/2017rosen1137/'}, {'work': 'http://www.loc.gov/item/46028327/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1431/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1431/'}, {'work': 'http://www.loc.gov/item/66089554/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1432/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1432/'}, {'work': 'http://www.loc.gov/item/65058999/', 'volume': 'https://www.loc.gov/resource/rbc0001.2014rosen1131/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2014/2014rosen1131/'}, {'work': 'http://www.loc.gov/item/49030941/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen1133/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen1133/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967a/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967a/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967b/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967b/'}, {'work': 'http://www.loc.gov/item/48037381/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen0881/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen0881/'}, {'work': 'http://www.loc.gov/item/48033299/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1284/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1284/'}, {'work': 'http://www.loc.gov/item/48034140/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0193/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0193/'}, {'work': 'http://www.loc.gov/item/48034144/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0195/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0195/'}, {'work': 'http://www.loc.gov/item/48034881/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0196/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0196/'}, {'work': 'http://www.loc.gov/item/47043543/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0744/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0744/'}, {'work': 'http://www.loc.gov/item/50041712/', 'volume': 'https://www.loc.gov/resource/rbc0001.2003rosen0014/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2003/2003rosen0014/'}, {'work': 'http://www.loc.gov/item/49032037/', 'volume': 'https://www.loc.gov/resource/rbc0001.2003rosen1094/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2003/2003rosen1094/'}, {'work': 'http://www.loc.gov/item/54001909/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen0923/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen0923/'}, {'work': 'http://www.loc.gov/item/65059067/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen1299/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen1299/'}, {'work': 'http://www.loc.gov/item/48042317/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen
', 'cdn': 'https://cdn.loc.gov/service/rbc/rbctos/2017/2017rosen1137/'}, {'work': 'http://www.loc.gov/item/46028327/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1431/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1431/'}, {'work': 'http://www.loc.gov/item/66089554/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1432/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1432/'}, {'work': 'http://www.loc.gov/item/65058999/', 'volume': 'https://www.loc.gov/resource/rbc0001.2014rosen1131/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2014/2014rosen1131/'}, {'work': 'http://www.loc.gov/item/49030941/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen1133/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen1133/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967a/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967a/'}, {'work': 'http://www.loc.gov/item/48033822/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0967b/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2008/2008rosen0967b/'}, {'work': 'http://www.loc.gov/item/48037381/', 'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen0881/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen0881/'}, {'work': 'http://www.loc.gov/item/48033299/', 'volume': 'https://www.loc.gov/resource/rbc0001.2013rosen1284/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2013/2013rosen1284/'}, {'work': 'http://www.loc.gov/item/48034140/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0193/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0193/'}, {'work': 'http://www.loc.gov/item/48034144/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0195/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0195/'}, {'work': 'http://www.loc.gov/item/48034881/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0196/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0196/'}, {'work': 'http://www.loc.gov/item/47043543/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen0744/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen0744/'}, {'work': 'http://www.loc.gov/item/50041712/', 'volume': 'https://www.loc.gov/resource/rbc0001.2003rosen0014/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2003/2003rosen0014/'}, {'work': 'http://www.loc.gov/item/49032037/', 'volume': 'https://www.loc.gov/resource/rbc0001.2003rosen1094/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2003/2003rosen1094/'}, {'work': 'http://www.loc.gov/item/54001909/', 'volume': 'https://www.loc.gov/resource/rbc0001.2016rosen0923/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2016/2016rosen0923/'}, {'work': 'http://www.loc.gov/item/65059067/', 'volume': 'https://www.loc.gov/resource/rbc0001.2017rosen1299/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2017/2017rosen1299/'}, {'work': 'http://www.loc.gov/item/48042317/', 'volume': 'https://www.loc.gov/resource/rbc0001.2008rosen0097/', 'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/ ...

# %%
len(work_volume_list)
# Out:
# 357

# %%
work_volume_list[:5]
# Out:
# [{'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v3/',
#   'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v1/',
#   'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v1/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v4/',
#   'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v4/'},
#  {'work': 'http://www.loc.gov/item/51006716/',
#   'volume': 'https://www.loc.gov/resource/rbc0001.2009rosen1938v2/',
#   'cdn': 'https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v2/'},
#  {'work': 'http://www.loc.gov/item/65059076/',
#   'volume': 'https://www.loc.gov/resource/rbctos.2017rosen1137/',
#   'cdn': 'https://cdn.loc.gov/service/rbc/rbctos/2017/2017rosen1137/'}]

# %%
# change to download somewhere other than inside this directory
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
import os
from requests.exceptions import HTTPError

# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0001v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0002v.jpg

def get_image_files(image_urls_list, dir_name):
    '''
    Takes as input a list of URLs for loc.gov item pages and 
    a path to a directory in which to save image files, e.g. "data". 
    '''    
    for count, url in enumerate(image_urls_list):
                
        if count % 100 == 0:
            print("at item {0}".format(count))
        
        # for each volume, initialize first image
        i = 1
        
        # function checks if image exists
        def url_validator(url):
            try:
                r = requests.get(url)
                r.raise_for_status()
                
            except HTTPError:
                
                return "404"
        
        # assume each volume has at least one image, "0001"
        is_valid_url = "200"
            
        while (is_valid_url != "404"):
                         
            try:
                # create a string in format "0001", ..."0254"
                image = str(i).zfill(4)

                # http://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0254v.jpg
                full_url = f"{url['cdn']}{image}v.jpg"

                # do some ugly stuff to generate an image name for download
                string_array = full_url.split("/")
                
                image_name = "-".join(string_array[5:])

                filename = os.path.join(dir_name, image_name)       

                # @TODO refactor to use image_response to check url validity
                image_response = requests.get(full_url, stream=True)
                
                with open(filename, 'wb') as fd:
                    for chunk in image_response.iter_content(chunk_size=100000):
                        fd.write(chunk)
                
                # increment image number
                i += 1
                
                # don't repeat yourself!
                image = str(i).zfill(4)

                full_url = f"{url['cdn']}{image}v.jpg"
                
                # check if the new image url is valid
                is_valid_url = url_validator(full_url)
            
                print(full_url)

            except ConnectionError as e:
                print(e)

# %%
get_image_files(work_volume_list, "images")
# Out:
# at item 0
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0002v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0003v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0004v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0005v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0006v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0007v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0008v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0009v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0010v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0011v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0012v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0013v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0014v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0015v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0016v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0017v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0018v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0019v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0020v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0021v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0022v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0023v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0024v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0025v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0026v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0027v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0028v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0029v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0030v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0031v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0032v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0033v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0034v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0035v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0036v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0037v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0038v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0039v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0040v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0041v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0042v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0043v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0044v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0045v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0046v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0047v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0048v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0049v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0050v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0051v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0052v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0053v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0054v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0055v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0056v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0057v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0058v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0059v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0060v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0061v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0062v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0063v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0064v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0065v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0066v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0067v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0068v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0069v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0070v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0071v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0072v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0073v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0074v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0075v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0076v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0077v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0078v.jpg
# https://cdn.loc.gov/service/rbc/rbc0001/2009/2009rosen1938v3/0079v.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8f17ec3ebc0e> in <module>
# ----> 1 get_image_files(work_volume_list, "images")
#
# <ipython-input-6-90f94609632f> in get_image_files(image_urls_list, dir_name)
#      63
#      64                 # check if the new image url is valid
# ---> 65                 is_valid_url = url_validator(full_url)
#      66
#      67                 print(full_url)
#
# <ipython-input-6-90f94609632f> in url_validator(url)
#      21         def url_validator(url):
#      22             try:
# ---> 23                 r = requests.get(url)
#      24                 r.raise_for_status()
#      25
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     319     if ca_certs or ca_cert_dir:
#     320         try:
# --> 321             context.load_verify_locations(ca_certs, ca_cert_dir)
#     322         except IOError as e:  # Platform-specific: Python 2.7
#     323             raise SSLError(e)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     426         if capath is not None:
#     427             capath = capath.encode('utf-8')
# --> 428         self._ctx.load_verify_locations(cafile, capath)
#     429         if cadata is not None:
#     430             self._ctx.load_verify_locations(BytesIO(cadata))
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in load_verify_locations(self, cafile, capath)
#     776
#     777         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 778             self._context, cafile, capath
#     779         )
#     780         if not load_result:
#
# KeyboardInterrupt:

# %%
! ls -la images

# %% [markdown]
# ### Connecting the image file to the metadata
# The filename the code creates is the item's identifier, so you reconstruct a URL for the item's metadata. For example, to examine at the metadata for the first item in the list, 2007685715.jpg, you can add ``https://www.loc.gov/item/`` before the identifier.
#
# ``https://www.loc.gov/item/2007685715``
#
# You can also request the metadata in JSON format by adding ``?fo=json&at=item`` at the end.

# %%
r = requests.get("https://www.loc.gov/item/2007685715/?fo=json")
r_data = r.json()
print(json.dumps(r_data["item"], indent=2))
